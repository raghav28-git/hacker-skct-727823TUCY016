# %% [markdown]
# # Custom Wordlist Generator
#
# This notebook demonstrates the working of the Custom Wordlist Generator tool.

# %%
import os
import sys

sys.path.append(os.path.abspath("../code"))

from tool_main import generate_wordlist

result = generate_wordlist("raghav", "28012006", "jim", "gun")

for word in result:
    print(word)

# %% [markdown]
# ## Output
#
# The tool generates multiple password combinations based on user inputs.
